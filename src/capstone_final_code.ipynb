# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\adity\OneDrive\Desktop\Capstone final\default of credit card clients.xls")
df.head()
# Out:
#   Unnamed: 0         X1   X2         X3        X4   X5     X6     X7     X8  \
# 0         ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3
# 1          1      20000    2          2         1   24      2      2     -1
# 2          2     120000    2          2         2   26     -1      2      0
# 3          3      90000    2          2         2   34      0      0      0
# 4          4      50000    2          2         1   37      0      0      0
#
#       X9  ...        X15        X16        X17       X18       X19       X20  \
# 0  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3
# 1     -1  ...          0          0          0         0       689         0
# 2      0  ...       3272       3455       3261         0      1000      1000
# 3      0  ...      14331      14948      15549      1518      1500      1000
# 4      0  ...      28314      28959      29547      2000      2019      1200
#
#         X21       X22       X23                           Y
# 0  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 1         0         0         0                           1
# 2      1000         0      2000                           1
# 3      1000      1000      5000                           0
# 4      1100      1069      1000                           0
#
# [5 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'X1', 'X2', 'X3', 'X4', 'X5', 'X6', 'X7', 'X8', 'X9',
#        'X10', 'X11', 'X12', 'X13', 'X14', 'X15', 'X16', 'X17', 'X18', 'X19',
#        'X20', 'X21', 'X22', 'X23', 'Y'],
#       dtype='object')

# %% [markdown]
# renaming some of the names of the columns for better understanding

# %%
#Rename Column  names
df.rename(columns={'X1': 'LIMIT_BAL', 'Unnamed: 0': 'ID', 'X2' : 'SEX', 'X3' : 'EDUCATION', 'X4' : 'MARRIAGE', 'X5' : 'AGE'}, inplace=True)

# %%
column_names = {
    'history_names': {
        'X6':'Sep_History','X11':'Apr_History','X7':'Aug_History',
        'X8':'Jul_History','X9':'Jun_History','X10':'May_History'
    },
    'balance_names': {
        'X12':'Sep_Bal','X13':'Aug_Bal','X14':'Jul_Bal',
        'X15':'Jun_Bal','X16':'May_Bal','X17':'Apr_Bal'
    },
    'payment_names': {
        'X18':'Sep_Pmt','X19':'Aug_Pmt','X20':'Jul_Pmt',
        'X21':'Jun_Pmt','X22':'May_Pmt','X23':'Apr_Pmt'
    }
}

for column_name in column_names:
    df.rename(columns=column_names[column_name], inplace=True)

# %% [markdown]
# renaming columns in the DataFrame df based on the mappings provided in the column_names dictionary.

# %%
df.rename(columns={'Y': 'DEF_PAY'}, inplace=True)

# %%
df = df.drop([0])

# %%
df.columns
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'Sep_History',
#        'Aug_History', 'Jul_History', 'Jun_History', 'May_History',
#        'Apr_History', 'Sep_Bal', 'Aug_Bal', 'Jul_Bal', 'Jun_Bal', 'May_Bal',
#        'Apr_Bal', 'Sep_Pmt', 'Aug_Pmt', 'Jul_Pmt', 'Jun_Pmt', 'May_Pmt',
#        'Apr_Pmt', 'DEF_PAY'],
#       dtype='object')

# %%
df.head()
# Out:
#   ID LIMIT_BAL SEX EDUCATION MARRIAGE AGE Sep_History Aug_History Jul_History  \
# 1  1     20000   2         2        1  24           2           2          -1
# 2  2    120000   2         2        2  26          -1           2           0
# 3  3     90000   2         2        2  34           0           0           0
# 4  4     50000   2         2        1  37           0           0           0
# 5  5     50000   1         2        1  57          -1           0          -1
#
#   Jun_History  ... Jun_Bal May_Bal Apr_Bal Sep_Pmt Aug_Pmt Jul_Pmt Jun_Pmt  \
# 1          -1  ...       0       0       0       0     689       0       0
# 2           0  ...    3272    3455    3261       0    1000    1000    1000
# 3           0  ...   14331   14948   15549    1518    1500    1000    1000
# 4           0  ...   28314   28959   29547    2000    2019    1200    1100
# 5           0  ...   20940   19146   19131    2000   36681   10000    9000
#
#   May_Pmt Apr_Pmt DEF_PAY
# 1       0       0       1
# 2       0    2000       1
# 3    1000    5000       0
# 4    1069    1000       0
# 5     689     679       0
#
# [5 rows x 25 columns]

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.isnull().sum()
# Out:
# ID             0
# LIMIT_BAL      0
# SEX            0
# EDUCATION      0
# MARRIAGE       0
# AGE            0
# Sep_History    0
# Aug_History    0
# Jul_History    0
# Jun_History    0
# May_History    0
# Apr_History    0
# Sep_Bal        0
# Aug_Bal        0
# Jul_Bal        0
# Jun_Bal        0
# May_Bal        0
# Apr_Bal        0
# Sep_Pmt        0
# Aug_Pmt        0
# Jul_Pmt        0
# Jun_Pmt        0
# May_Pmt        0
# Apr_Pmt        0
# DEF_PAY        0
# dtype: int64

# %%
df.dtypes
# Out:
# ID             object
# LIMIT_BAL      object
# SEX            object
# EDUCATION      object
# MARRIAGE       object
# AGE            object
# Sep_History    object
# Aug_History    object
# Jul_History    object
# Jun_History    object
# May_History    object
# Apr_History    object
# Sep_Bal        object
# Aug_Bal        object
# Jul_Bal        object
# Jun_Bal        object
# May_Bal        object
# Apr_Bal        object
# Sep_Pmt        object
# Aug_Pmt        object
# Jul_Pmt        object
# Jun_Pmt        object
# May_Pmt        object
# Apr_Pmt        object
# DEF_PAY        object
# dtype: object

# %%
col = df.columns
for i in col:
  df[i] = df[i].astype(int)

df.dtypes
# Out:
# ID             int32
# LIMIT_BAL      int32
# SEX            int32
# EDUCATION      int32
# MARRIAGE       int32
# AGE            int32
# Sep_History    int32
# Aug_History    int32
# Jul_History    int32
# Jun_History    int32
# May_History    int32
# Apr_History    int32
# Sep_Bal        int32
# Aug_Bal        int32
# Jul_Bal        int32
# Jun_Bal        int32
# May_Bal        int32
# Apr_Bal        int32
# Sep_Pmt        int32
# Aug_Pmt        int32
# Jul_Pmt        int32
# Jun_Pmt        int32
# May_Pmt        int32
# Apr_Pmt        int32
# DEF_PAY        int32
# dtype: object

# %%
for i in col:
  print (i,df[i].min(), df[i].max())
# Out:
# ID 1 30000
# LIMIT_BAL 10000 1000000
# SEX 1 2
# EDUCATION 0 6
# MARRIAGE 0 3
# AGE 21 79
# Sep_History -2 8
# Aug_History -2 8
# Jul_History -2 8
# Jun_History -2 8
# May_History -2 8
# Apr_History -2 8
# Sep_Bal -165580 964511
# Aug_Bal -69777 983931
# Jul_Bal -157264 1664089
# Jun_Bal -170000 891586
# May_Bal -81334 927171
# Apr_Bal -339603 961664
# Sep_Pmt 0 873552
# Aug_Pmt 0 1684259
# Jul_Pmt 0 896040
# Jun_Pmt 0 621000
# May_Pmt 0 426529
# Apr_Pmt 0 528666
# DEF_PAY 0 1

# %% [markdown]
#  extracting the unique values from the specified column, and sorting these values.

# %%
print('SEX' + str(sorted(df['SEX'].unique())))
print('EDUCATION' + str(sorted(df['EDUCATION'].unique())))
print('MARRIAGE' + str(sorted(df['MARRIAGE'].unique())))
print('Sep_History' + str(sorted(df['Sep_History'].unique())))
print('DEF_PAY' + str(sorted(df['DEF_PAY'].unique())))
# Out:
# SEX[1, 2]
# EDUCATION[0, 1, 2, 3, 4, 5, 6]
# MARRIAGE[0, 1, 2, 3]
# Sep_History[-2, -1, 0, 1, 2, 3, 4, 5, 6, 7, 8]
# DEF_PAY[0, 1]

# %% [markdown]
# data preprocessing steps to categorize the certain values in DataFrame df.

# %%
# Some categories are undocumented

# The 0, 5 and 6 in EDUCATION can be categorized as 'Other' (4)
fill = (df['EDUCATION']==0) | (df['EDUCATION']==5) | (df['EDUCATION']==6)
df.loc[fill, 'EDUCATION']=4

# The 0 in MARRIAGE can be categorized as 'Other' (3)
df.loc[df['MARRIAGE']==0, 'MARRIAGE']=3

# The -2, -1 and 0 in PAY_n can be categorized as 'duly' (0)
fill = (df['Sep_History']==-2) | (df['Sep_History']==-1) | (df['Sep_History']==0)
df.loc[fill, 'Sep_History']=0

fill = (df['Aug_History']==-2) | (df['Aug_History']==-1) | (df['Aug_History']==0)
df.loc[fill, 'Aug_History']=0

fill = (df['Jul_History']==-2) | (df['Jul_History']==-1) | (df['Jul_History']==0)
df.loc[fill, 'Jul_History']=0

fill = (df['Jun_History']==-2) | (df['Jun_History']==-1) | (df['Jun_History']==0)
df.loc[fill, 'Jun_History']=0

fill = (df['May_History']==-2) | (df['May_History']==-1) | (df['May_History']==0)
df.loc[fill, 'May_History']=0

fill = (df['Apr_History']==-2) | (df['Apr_History']==-1) | (df['Apr_History']==0)
df.loc[fill, 'Apr_History']=0

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  Sep_History  Aug_History  \
# 1   1      20000    2          2         1   24            2            2
# 2   2     120000    2          2         2   26            0            2
# 3   3      90000    2          2         2   34            0            0
# 4   4      50000    2          2         1   37            0            0
# 5   5      50000    1          2         1   57            0            0
#
#    Jul_History  Jun_History  ...  Jun_Bal  May_Bal  Apr_Bal  Sep_Pmt  Aug_Pmt  \
# 1            0            0  ...        0        0        0        0      689
# 2            0            0  ...     3272     3455     3261        0     1000
# 3            0            0  ...    14331    14948    15549     1518     1500
# 4            0            0  ...    28314    28959    29547     2000     2019
# 5            0            0  ...    20940    19146    19131     2000    36681
#
#    Jul_Pmt  Jun_Pmt  May_Pmt  Apr_Pmt  DEF_PAY
# 1        0        0        0        0        1
# 2     1000     1000        0     2000        1
# 3     1000     1000     1000     5000        0
# 4     1200     1100     1069     1000        0
# 5    10000     9000      689      679        0
#
# [5 rows x 25 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Correlation plot 
fig, ax = plt.subplots(figsize=(20, 12))
dfcorr=df.corr()
sns.heatmap(dfcorr, annot=True).set(title="Credit card data");

# %%
plt.figure(figsize=(11,5))
sns.set_style('white')
ax = sns.countplot(data=df, x='DEF_PAY', palette='Blues')

ax.set_xlabel('Default payment', fontsize=12)
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.4, p.get_height()), ha='center', va='top', color='black', size=12)

plt.ylim(0,25000)
plt.annotate('More than 6,636 out of 30,000 of \nclients will default next month.', xy=(0.595, 15000), fontsize=13)
plt.xticks([0,1],['Not default', 'Default'], fontsize=13); plt.ylabel('Number of clients', fontsize=12)
plt.show()

# %%
# Calculate the value counts for 'DEF_PAY' column
value_counts = df['DEF_PAY'].value_counts()

# Define the labels and colors for the pie chart
labels = ['Not default', 'Default']
colors = ['#B3CEDE', '#4884AF']

# Define the explode parameter (to emphasize a slice)
explode = (0, 0.1)

# Create the pie chart
plt.figure(figsize=(5, 5))
plt.pie(value_counts, labels=labels, autopct='%1.1f%%', colors=colors, explode=explode, textprops={"fontsize": 12})
plt.title('Distribution of Default vs. Not Default')
plt.show()

# %% [markdown]
# The chart can help identify the relative size of the "Default" category, which is crucial for risk management and designing appropriate lending policies.

# %%
plt.figure(figsize=(14, 8))
plt.title('Credit Limit Amount - Probability Density')
plt.ticklabel_format(style='plain', axis='x')

plt.hist(df['LIMIT_BAL'], bins=100, color="red", density=True, alpha=0.6, edgecolor='black')
plt.xlabel('Credit Limit Amount')
plt.ylabel('Probability Density')

plt.show()

# %%
plt.figure(figsize=(9,4))
sns.kdeplot(data=df, x='AGE', hue='DEF_PAY', multiple='stack', palette='Blues')

plt.legend(loc='upper right', labels=['Default', 'Not default'])
plt.ylabel('Density', fontsize= 12)
plt.show()

# %% [markdown]
# In this specific visualization, the data appears to be right-skewed, with a concentration of lower credit limits and a tail extending to higher values.
#
# The majority of accounts seem to have relatively lower credit limits, while a smaller proportion has higher credit limits.

# %%
plt.figure(figsize=(14,10))
sns.set_context('talk', font_scale=0.8)

ax = sns.countplot(data=df, x='EDUCATION', hue='DEF_PAY', palette='Blues')
for p in ax.patches:
    ax.annotate(f'\n{p.get_height()}', (p.get_x()+0.2, p.get_height()+800), ha='center', va='top', color='black', size=12)

plt.ylim(0,12000)
plt.xticks([0,1,2,3], ['Grad School', 'University', 'High School', 'Others'], fontsize=12);plt.ylabel('Number of clients', fontsize = 14)
plt.legend(labels=['Not default', 'Default'], fontsize=12)
plt.show()

# %% [markdown]
# This visualization allows us to observe how default status varies across different education levels. It helps answer questions such as whether clients with higher educational backgrounds are less likely to default or whether there are variations in default rates across education categories.

# %%
plt.figure(figsize=(13,7))
sns.set_style('white')

ax = sns.barplot(x='EDUCATION', y='DEF_PAY', data=df, palette='Blues', ci=None)

for p in ax.patches:
    ax.annotate('%.2f' %(p.get_height()), (p.get_x()+0.30, p.get_height()+0.01), size=12)

plt.ylabel('% of default', fontsize= 12)
plt.ylim(0,0.5)
plt.xticks([0,1,2,3],['Grad School', 'University', 'High School', 'Others'], fontsize = 12); plt.xlabel('EDUCATION', fontsize = 12)
plt.show()

# %% [markdown]
# The height of the bars indicates the percentage of clients within each education category who have faced defaults.

# %%
plt.figure(figsize=(12,8))
sns.set_style('white')

ax = sns.countplot(data=df, y='MARRIAGE', hue='DEF_PAY', palette='Blues')

for p in ax.patches:
  height = p.get_height()
  width = p.get_width()
  ax.text(x=width+3,
  y = p.get_y()+(height/2),
  s = '{:.0f}'.format(width),
  va = 'center')

plt.xlim(0,15000)
plt.ylabel('MARITAL STATUS', fontsize=13)
plt.yticks([0,1,2],['Married','Single','Others'], fontsize=12);plt.xlabel('Number of clients', fontsize=13)
plt.legend(labels=['Not default', 'Default'])
plt.show()

# %% [markdown]
# This visualization allows us to observe how default status varies across different marital status categories. It helps answer questions such as whether clients with specific marital statuses are more or less likely to default or whether there are variations in default rates across marital status groups.
#
# . It helps us understand the potential correlation between marital status and credit default within the dataset.

# %%
# Average payment over time
monthly_payments = ['Apr_Pmt', 'May_Pmt', 'Jun_Pmt',
                    'Jul_Pmt', 'Aug_Pmt', 'Sep_Pmt']
avg_pmt = []

for month in monthly_payments:
    avg_pmt.append(df[month].mean())

plt.figure(figsize=(10,6))
plt.plot(monthly_payments, avg_pmt)
plt.title('Average Payment Over Time ($)')
plt.show();

# %% [markdown]
# this visualization helps us to determine whether clients tend to make larger or smaller payments during certain months.
#
# This information can be valuable for understanding client behavior, budgeting trends, and assessing financial patterns.
#
# For financial institutions, it may be useful for predicting future cash flows, assessing client creditworthiness, or optimizing payment collection strategies.

# %% [markdown]
# # Data Splitting

# %%
from tqdm import tqdm_notebook
from sklearn.preprocessing import StandardScaler
from  sklearn.model_selection import train_test_split 
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, roc_curve, classification_report, confusion_matrix, f1_score, accuracy_score, precision_score, recall_score
# %matplotlib inline

# %%
with pd.option_context("display.max_columns", None):
    display(df)
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  Sep_History  \
# 1          1      20000    2          2         1   24            2
# 2          2     120000    2          2         2   26            0
# 3          3      90000    2          2         2   34            0
# 4          4      50000    2          2         1   37            0
# 5          5      50000    1          2         1   57            0
# ...      ...        ...  ...        ...       ...  ...          ...
# 29996  29996     220000    1          3         1   39            0
# 29997  29997     150000    1          3         2   43            0
# 29998  29998      30000    1          2         2   37            4
# 29999  29999      80000    1          3         1   41            1
# 30000  30000      50000    1          2         1   46            0
#
#        Aug_History  Jul_History  Jun_History  May_History  Apr_History  \
# 1                2            0            0            0            0
# 2                2            0            0            0            2
# 3                0            0            0            0            0
# 4                0            0            0            0            0
# 5                0            0            0            0            0
# ...            ...          ...          ...          ...          ...
# 29996            0            0            0            0            0
# 29997            0            0            0            0            0
# 29998            3            2            0            0            0
# 29999            0            0            0            0            0
# 30000            0            0            0            0            0
#
#        Sep_Bal  Aug_Bal  Jul_Bal  Jun_Bal  May_Bal  Apr_Bal  Sep_Pmt  Aug_Pmt  \
# 1         3913     3102      689        0        0        0        0      689
# 2         2682     1725     2682     3272     3455     3261        0     1000
# 3        29239    14027    13559    14331    14948    15549     1518     1500
# 4        46990    48233    49291    28314    28959    29547     2000     2019
# 5         8617     5670    35835    20940    19146    19131     2000    36681
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 29996   188948   192815   208365    88004    31237    15980     8500    20000
# 29997     1683     1828     3502     8979     5190        0     1837     3526
# 29998     3565     3356     2758    20878    20582    19357        0        0
# 29999    -1645    78379    76304    52774    11855    48944    85900     3409
# 30000    47929    48905    49764    36535    32428    15313     2078     1800
#
#        Jul_Pmt  Jun_Pmt  May_Pmt  Apr_Pmt  DEF_PAY
# 1            0        0        0        0        1
# 2         1000     1000        0     2000        1
# 3         1000     1000     1000     5000        0
# 4         1200     1100     1069     1000        0
# 5        10000     9000      689      679        0
# ...        ...      ...      ...      ...      ...
# 29996     5003     3047     5000     1000        0
# 29997     8998      129        0        0        0
# 29998    22000     4200     2000     3100        1
# 29999     1178     1926    52964     1804        1
# 30000     1430     1000     1000     1000        1
#
# [30000 rows x 25 columns]

# %%
X = df.iloc[:,:-1]
y = df['DEF_PAY']

# %%
#Split the data
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size=0.25, random_state=0)

# %% [markdown]
# # Scaling

# %%
for i in col:
  print (i,df[i].min(), df[i].max())
# Out:
# ID 1 30000
# LIMIT_BAL 10000 1000000
# SEX 1 2
# EDUCATION 1 4
# MARRIAGE 1 3
# AGE 21 79
# Sep_History 0 8
# Aug_History 0 8
# Jul_History 0 8
# Jun_History 0 8
# May_History 0 8
# Apr_History 0 8
# Sep_Bal -165580 964511
# Aug_Bal -69777 983931
# Jul_Bal -157264 1664089
# Jun_Bal -170000 891586
# May_Bal -81334 927171
# Apr_Bal -339603 961664
# Sep_Pmt 0 873552
# Aug_Pmt 0 1684259
# Jul_Pmt 0 896040
# Jun_Pmt 0 621000
# May_Pmt 0 426529
# Apr_Pmt 0 528666
# DEF_PAY 0 1

# %%
# Normalizing input variables of Train data to same scale
scalar = StandardScaler()
X_train = scalar.fit_transform(X_train)

# %%
df['DEF_PAY'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: DEF_PAY, dtype: int64

# %%
y_train.value_counts()
# Out:
# 0    17496
# 1     5004
# Name: DEF_PAY, dtype: int64

# %%
# Applting SMOTE technique to balance the data
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
X_train, y_train = sm.fit_resample(X_train, y_train)
X_test, y_test = sm.fit_resample(X_test, y_test)

# %%
y_train.value_counts()
# Out:
# 0    17496
# 1    17496
# Name: DEF_PAY, dtype: int64

# %%
y_test.value_counts()
# Out:
# 0    5868
# 1    5868
# Name: DEF_PAY, dtype: int64

# %%
# Normalizing input variables of Test data to same scale
scalar = StandardScaler()
X_test = scalar.fit_transform(X_test)

# %% [markdown]
# # **Model Selection and Model Exploration**

# %% [markdown]
# # MIXED NAIVE BIAS

# %%
pip install mixed-naive-bayes
# Out:
# Requirement already satisfied: mixed-naive-bayes in c:\users\adity\anaconda3\lib\site-packages (0.0.3)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\adity\anaconda3\lib\site-packages (from mixed-naive-bayes) (1.22.4)
# Requirement already satisfied: scikit-learn>=0.20.2 in c:\users\adity\anaconda3\lib\site-packages (from mixed-naive-bayes) (1.1.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\adity\anaconda3\lib\site-packages (from scikit-learn>=0.20.2->mixed-naive-bayes) (1.7.1)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\adity\anaconda3\lib\site-packages (from scikit-learn>=0.20.2->mixed-naive-bayes) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\adity\anaconda3\lib\site-packages (from scikit-learn>=0.20.2->mixed-naive-bayes) (3.1.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mixed_naive_bayes import MixedNB
from sklearn.preprocessing import LabelEncoder
X1 = df.iloc[:,:-1].values
y1 = df['DEF_PAY'].values
X1 = np.array(X1)
y1 = np.array(y1)
label_encoder = LabelEncoder()
X1[:,2] = label_encoder.fit_transform(X1[:,2])
X1[:,3] = label_encoder.fit_transform(X1[:,3])
X1[:,4] = label_encoder.fit_transform(X1[:,4])
X1[:,6] = label_encoder.fit_transform(X1[:,6])
X1[:,7] = label_encoder.fit_transform(X1[:,7])
X1[:,8] = label_encoder.fit_transform(X1[:,8])
X1[:,9] = label_encoder.fit_transform(X1[:,9])
X1[:,10] = label_encoder.fit_transform(X1[:,10])
X1[:,11] = label_encoder.fit_transform(X1[:,11])
clf = MixedNB(categorical_features=[2,3,4,6,7,8,9,10,11])
clf.fit(X1,y1)
clf.predict(X1)
# Out:
# C:\Users\adity\anaconda3\lib\site-packages\mixed_naive_bayes\mixed_naive_bayes.py:275: RuntimeWarning: invalid value encountered in true_divide
#   normalised = finals/finals.sum(axis=1, keepdims=True)
# array([1, 1, 0, ..., 1, 0, 1], dtype=int64)

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y1, test_size=0.2,random_state=3)

# %%
# Finding the predictions of gaussian naive Bayes for train and test subsets
train_y_pred = clf.predict(X_train1)
test_y_pred = clf.predict(X_test1)

# %%
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
train_score = metrics.accuracy_score(y_train1, train_y_pred) # Compute train␣ , →accuracy
test_score = metrics.accuracy_score(y_test1, test_y_pred) # Compute test␣ , →accuracy
train_report = classification_report(y_train1, train_y_pred) # Generate␣ , →classification report for train data
test_report = classification_report(y_test1, test_y_pred) # Generate␣ , →classification report for test data
print('Mixed NB Train Classification Report: \n\n', train_report,'\n\n')
print('Mixed NB Test Classification Report: \n\n', test_report)
# Out:
# Mixed NB Train Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.89      0.64      0.75     18616
#            1       0.37      0.72      0.49      5384
#
#     accuracy                           0.66     24000
#    macro avg       0.63      0.68      0.62     24000
# weighted avg       0.77      0.66      0.69     24000
#
#
#
# Mixed NB Test Classification Report:
#
#                precision    recall  f1-score   support
#
#            0       0.90      0.65      0.75      4748
#            1       0.35      0.73      0.48      1252
#
#     accuracy                           0.66      6000
#    macro avg       0.63      0.69      0.61      6000
# weighted avg       0.79      0.66      0.69      6000

# %% [markdown]
# # Logistic Regression

# %%
class LogisticRegression:
  def __init__(self, X, y, learningRate, tolerance, maxIteration):
      self.X=X
      self.y=y
      self.learningRate = learningRate
      self.tolerance =  tolerance
      self.maxIteration = maxIteration
  
  def addX0(self, X):
    return np.column_stack([np.ones(X.shape[0]),X])

  def sigmoid(self, z):
    sig =  1 / (1 +  np.exp(-z))
    return sig

  def costFunction(self, X, y):
    pred_ = np.log(np.ones(X.shape[0]) + np.exp(X.dot(self.w))) - X.dot(self.w).dot(y)
    cost = pred_.sum()
    return cost
    
  def gradient(self, X, y):
    sig = self.sigmoid(X.dot(self.w))
    grad = (sig - y).dot(X)
    return grad
  
  def gradientDescent(self, X, y):
    errors = []
    last = float('inf')

    for i in tqdm_notebook(range(self.maxIteration)):
      self.w = self.w - self.learningRate * self.gradient(X,y)
      curr = self.costFunction(X, y)
      diff = last - curr
      last = curr

      errors.append(curr)
      if diff < self.tolerance:
        print("Model Stopped")
        break
      
    self.plot_cost(errors)
    return

  def predict(self, X):
    sig = self.sigmoid(X.dot(self.w))
    return np.around(sig)

    
  def evaluate(self, y, y_hat):
    test_error = []
    y = (y == 1)
    y_hat = (y_hat == 1)

    accuracy = (y==y_hat).sum() / y.size
    precision = (y & y_hat).sum() / y_hat.sum()
    recall = (y & y_hat).sum() / y.sum()
    

    fScore = 2* (precision*recall) / (precision+recall)
    return fScore, recall, precision, accuracy

  def run_model(self, X_test, y_test ):
    self.X_train =  self.X
    self.y_train = self.y
    self.X_test = X_test
    self.y_test = y_test
    self.w = np.ones(self.X.shape[1], dtype= np.float64) * 0
    self.gradientDescent(self.X, self.y)

    y_hat_train = self.predict(self.X)
    fScore, accuracy, recall, precision = self.evaluate(self.y, y_hat_train)

    print("Training set Performance")
    print(confusion_matrix(self.y, y_hat_train))
    print("F1_Score is :" , fScore)
    print("Accuracy is :" , accuracy)
    print("Precision is :" , precision)
    print("Recall is :" , recall)


    y_hat_test = self.predict(self.X_test)
    fScore, accuracy, recall, precision = self.evaluate(self.y_test, y_hat_test)

    print("Test set Performance")
    print(confusion_matrix(self.y_test, y_hat_test))
    print("F1_Score is :" , fScore)
    print("Accuracy is :" , accuracy)
    print("Precision is :" , precision)
    print("Recall is :" , recall)
 
  def plot(self):
    plt.figure(figsize=(12, 8))
    ax = plt.axes(projection='3d')
    print(self.X_train[:, 0])
    print(self.self.X_train[:, 1])


        # Data for three-dimensional scattered points
    ax.scatter3D(self.X_train[:, 0], self.X_train[:, 1], self.sigmoid(self.X_train.dot(self.w)),c = self.y_train[:], cmap='viridis', s=100);

    ax.set_xlim3d(55, 80)
    ax.set_ylim3d(80, 240)
    plt.xlabel('$x_1$ feature', fontsize=15)
    plt.ylabel('$x_2$ feature', fontsize=15, )
    ax.set_zlabel('$P(Y = 1|x_1, x_2)$', fontsize=15, rotation = 0)
  
  def plot_cost(self, cost_sequence):
        # Data for plotting
    s = np.array(cost_sequence)
    t = np.arange(s.size)

    fig, ax = plt.subplots()
    ax.plot(t, s)

    ax.set(xlabel='iterations', ylabel='cost',
                title='cost trend')
    ax.grid()

    plt.legend(bbox_to_anchor=(1.05,1), loc=2, shadow=True)
    plt.show()

# %%
#learning rate:  1e-06  tolerance :  5e-07
lr = LogisticRegression(X_train, y_train, learningRate = 1e-06, tolerance = 5e-07, maxIteration=5000)
lr.run_model(X_test, y_test)
# Out:
# C:\Users\adity\AppData\Local\Temp/ipykernel_11936/919120524.py:30: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm_notebook(range(self.maxIteration)):
#   0%|          | 0/5000 [00:00<?, ?it/s]
# No handles with labels found to put in legend.
# Training set Performance
# [[13874  3622]
#  [ 6763 10733]]
# F1_Score is : 0.6739505823992968
# Accuracy is : 0.6134545038866026
# Precision is : 0.7032178783721994
# Recall is : 0.7476837338906305
# Test set Performance
# [[4938  930]
#  [2745 3123]]
# F1_Score is : 0.6295736316903539
# Accuracy is : 0.5322085889570553
# Precision is : 0.6868609406952966
# Recall is : 0.770540340488527

# %% [markdown]
# # Recurrent Neural Networks

# %%
# !pip install tensorflow-addons==0.16.1
# Out:
# Requirement already satisfied: tensorflow-addons==0.16.1 in c:\users\adity\anaconda3\lib\site-packages (0.16.1)
# Requirement already satisfied: typeguard>=2.7 in c:\users\adity\anaconda3\lib\site-packages (from tensorflow-addons==0.16.1) (2.13.3)
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install tensorflow-addons
# Out:
# Requirement already satisfied: tensorflow-addons in c:\users\adity\anaconda3\lib\site-packages (0.16.1)
# [notice] A new release of pip is available: 23.0.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: typeguard>=2.7 in c:\users\adity\anaconda3\lib\site-packages (from tensorflow-addons) (2.13.3)

# %%
# Importing basic tensorflow modules
from sklearn.metrics import f1_score
from tqdm.autonotebook import tqdm
import time
# Importing some basic modules in torch
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import BatchSampler, Dataset, DataLoader
import tensorflow as tf
from tensorflow.keras.layers import Dense, Activation, SimpleRNN, LSTM
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
import tensorflow_addons as tfa
from tensorflow.keras.utils import plot_model

# %%
with pd.option_context("display.max_columns", None):
    display(df.head())
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  Sep_History  Aug_History  \
# 1   1      20000    2          2         1   24            2            2
# 2   2     120000    2          2         2   26            0            2
# 3   3      90000    2          2         2   34            0            0
# 4   4      50000    2          2         1   37            0            0
# 5   5      50000    1          2         1   57            0            0
#
#    Jul_History  Jun_History  May_History  Apr_History  Sep_Bal  Aug_Bal  \
# 1            0            0            0            0     3913     3102
# 2            0            0            0            2     2682     1725
# 3            0            0            0            0    29239    14027
# 4            0            0            0            0    46990    48233
# 5            0            0            0            0     8617     5670
#
#    Jul_Bal  Jun_Bal  May_Bal  Apr_Bal  Sep_Pmt  Aug_Pmt  Jul_Pmt  Jun_Pmt  \
# 1      689        0        0        0        0      689        0        0
# 2     2682     3272     3455     3261        0     1000     1000     1000
# 3    13559    14331    14948    15549     1518     1500     1000     1000
# 4    49291    28314    28959    29547     2000     2019     1200     1100
# 5    35835    20940    19146    19131     2000    36681    10000     9000
#
#    May_Pmt  Apr_Pmt  DEF_PAY
# 1        0        0        1
# 2        0     2000        1
# 3     1000     5000        0
# 4     1069     1000        0
# 5      689      679        0

# %%
# Defining a function that arranges the dataset in the form of (B,T,d) numpy␣ , →array (T=n_day)
def time_sequence(df, n_day):
    X = []
    y = []
    for i in range(len(df)-n_day):
        a = []
        b = 0
        for j in range(n_day):
            a.append([df.iloc[i+j]['LIMIT_BAL'], df.iloc[i+j]['AGE'], df.iloc[i+j]['Sep_Bal'], df.iloc[i+j]['Aug_Bal'], df.iloc[i+j]['Jul_Bal'], df.iloc[i+j]['Jun_Bal'], df.iloc[i+j]['May_Bal'], df.iloc[i+j]['Apr_Bal'], df.iloc[i+j]['Sep_Pmt'], df.iloc[i+j]['Aug_Pmt'], df.iloc[i+j]['Jul_Pmt'], df.iloc[i+j]['Jun_Pmt'], df.iloc[i+j]['May_Pmt'], df.iloc[i+j]['Apr_Pmt']])
            b = df.iloc[i+j+1]['DEF_PAY'] 
        X.append(a)
        y.append(b)
    X = np.array(X)
    y = np.array(y)
    return X, y

# %%
# Creating a simple function that builds a simple RNN neural network
def create_rnn_model(n_neurons, shape, learning_rate):
    model = Sequential()
    model.add(SimpleRNN(n_neurons, input_shape=shape, activation='tanh')) #␣ , →One RNN layer
    model.add(Dense(1)) # A␣ , →linear layer to final output
    adam = Adam(learning_rate=learning_rate) #␣ , →Choice of optimizer
    # Compiling the model by specifying the choice of loss function ('mse'), and␣ , →performance metrics
    #model.compile(loss='mse', optimizer=adam, metrics=['mse', tfa.metrics.r_square.RSquare()])
    model.compile(loss='mse', optimizer='adam', metrics=[tfa.metrics.RSquare(dtype=tf.float32, y_shape=(1,))])
    return model

# %%
# Forming the sequence input data for the interval of 5 days
n_days = 5
start_time = time.time()
X, y = time_sequence(df, n_days)
print("Computing time: %s seconds" % (round(time.time() - start_time, 3)))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=3)
# Converting data into tensorflow tensor objects and presenting the shape of␣ , →tensors
X_train = tf.convert_to_tensor(X_train, dtype=tf.float32)
X_test = tf.convert_to_tensor(X_test, dtype=tf.float32)
y_train = tf.convert_to_tensor(y_train, dtype=tf.float32)
y_test = tf.convert_to_tensor(y_test, dtype=tf.float32)
# Creating an RNN model with 128 neurons and learning rate 0.001
#del rnn_model
rnn_model = create_rnn_model(n_neurons=128, shape=(X_train.shape[1], X_train.shape[2]), learning_rate=0.001)
# Training the model for 150 epochs
epochs = 150
rnn_model_history = rnn_model.fit(X_train, y_train, epochs=epochs, validation_data=(X_test, y_test), verbose=1)
# Plotting R^2 score from model's history
plt.figure(figsize=(8,5))
plt.plot(rnn_model_history.history['r_square'][30:], label = 'train r^2')
plt.plot(rnn_model_history.history['val_r_square'][30:], label = 'test r^2')
plt.title(r'$R^2$ of the Train and Test Subsets for the RNN Model')
plt.legend([r'train $R^2$', r'test $R^2$'])
plt.show()
# Out:
# Computing time: 202.817 seconds
# Epoch 1/150
# 703/703 [==============================] - 4s 4ms/step - loss: 0.2587 - r_square: -0.5035 - val_loss: 0.2129 - val_r_square: -0.2324
# Epoch 2/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1940 - r_square: -0.1271 - val_loss: 0.1884 - val_r_square: -0.0907
# Epoch 3/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1856 - r_square: -0.0782 - val_loss: 0.1967 - val_r_square: -0.1387
# Epoch 4/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1820 - r_square: -0.0574 - val_loss: 0.1809 - val_r_square: -0.0475
# Epoch 5/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1807 - r_square: -0.0501 - val_loss: 0.1781 - val_r_square: -0.0310
# Epoch 6/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1790 - r_square: -0.0399 - val_loss: 0.1768 - val_r_square: -0.0235
# Epoch 7/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1792 - r_square: -0.0412 - val_loss: 0.1776 - val_r_square: -0.0283
# Epoch 8/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1780 - r_square: -0.0346 - val_loss: 0.1777 - val_r_square: -0.0285
# Epoch 9/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1773 - r_square: -0.0305 - val_loss: 0.1763 - val_r_square: -0.0207
# Epoch 10/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1778 - r_square: -0.0332 - val_loss: 0.1785 - val_r_square: -0.0334
# Epoch 11/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1766 - r_square: -0.0259 - val_loss: 0.1766 - val_r_square: -0.0221
# Epoch 12/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1777 - r_square: -0.0328 - val_loss: 0.1816 - val_r_square: -0.0514
# Epoch 13/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1766 - r_square: -0.0262 - val_loss: 0.1958 - val_r_square: -0.1337
# Epoch 14/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1765 - r_square: -0.0254 - val_loss: 0.1782 - val_r_square: -0.0319
# Epoch 15/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1766 - r_square: -0.0265 - val_loss: 0.1786 - val_r_square: -0.0342
# Epoch 16/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1766 - r_square: -0.0260 - val_loss: 0.1757 - val_r_square: -0.0173
# Epoch 17/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1770 - r_square: -0.0288 - val_loss: 0.1756 - val_r_square: -0.0164
# Epoch 18/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1764 - r_square: -0.0249 - val_loss: 0.1749 - val_r_square: -0.0126
# Epoch 19/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1753 - r_square: -0.0187 - val_loss: 0.1907 - val_r_square: -0.1037
# Epoch 20/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1754 - r_square: -0.0194 - val_loss: 0.1945 - val_r_square: -0.1261
# Epoch 21/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1765 - r_square: -0.0254 - val_loss: 0.1823 - val_r_square: -0.0555
# Epoch 22/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1752 - r_square: -0.0180 - val_loss: 0.1745 - val_r_square: -0.0101
# Epoch 23/150
# 703/703 [==============================] - 4s 5ms/step - loss: 0.1758 - r_square: -0.0215 - val_loss: 0.1773 - val_r_square: -0.0263
# Epoch 24/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1755 - r_square: -0.0196 - val_loss: 0.1784 - val_r_square: -0.0327
# Epoch 25/150
# 703/703 [==============================] - 5s 7ms/step - loss: 0.1759 - r_square: -0.0224 - val_loss: 0.1743 - val_r_square: -0.0092
# Epoch 26/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1751 - r_square: -0.0173 - val_loss: 0.1803 - val_r_square: -0.0438
# Epoch 27/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1758 - r_square: -0.0215 - val_loss: 0.1753 - val_r_square: -0.0149
# Epoch 28/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1761 - r_square: -0.0234 - val_loss: 0.1854 - val_r_square: -0.0736
# Epoch 29/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1751 - r_square: -0.0175 - val_loss: 0.1796 - val_r_square: -0.0400
# Epoch 30/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1750 - r_square: -0.0169 - val_loss: 0.1740 - val_r_square: -0.0071
# Epoch 31/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1760 - r_square: -0.0229 - val_loss: 0.1746 - val_r_square: -0.0107
# Epoch 32/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1756 - r_square: -0.0206 - val_loss: 0.1771 - val_r_square: -0.0253
# Epoch 33/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1757 - r_square: -0.0207 - val_loss: 0.1738 - val_r_square: -0.0060
# Epoch 34/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1755 - r_square: -0.0200 - val_loss: 0.1738 - val_r_square: -0.0062
# Epoch 35/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1756 - r_square: -0.0205 - val_loss: 0.1855 - val_r_square: -0.0739
# Epoch 36/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1747 - r_square: -0.0153 - val_loss: 0.1926 - val_r_square: -0.1148
# Epoch 37/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1755 - r_square: -0.0199 - val_loss: 0.1738 - val_r_square: -0.0059
# Epoch 38/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1758 - r_square: -0.0214 - val_loss: 0.1770 - val_r_square: -0.0244
# Epoch 39/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1752 - r_square: -0.0180 - val_loss: 0.1741 - val_r_square: -0.0077
# Epoch 40/150
# 703/703 [==============================] - 6s 8ms/step - loss: 0.1752 - r_square: -0.0178 - val_loss: 0.1770 - val_r_square: -0.0247
# Epoch 41/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1752 - r_square: -0.0179 - val_loss: 0.1736 - val_r_square: -0.0050
# Epoch 42/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1755 - r_square: -0.0196 - val_loss: 0.1765 - val_r_square: -0.0220
# Epoch 43/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1764 - r_square: -0.0250 - val_loss: 0.1758 - val_r_square: -0.0177
# Epoch 44/150
# 703/703 [==============================] - 133s 189ms/step - loss: 0.1768 - r_square: -0.0274 - val_loss: 0.1786 - val_r_square: -0.0341
# Epoch 45/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1759 - r_square: -0.0218 - val_loss: 0.1756 - val_r_square: -0.0167
# Epoch 46/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1747 - r_square: -0.0152 - val_loss: 0.1830 - val_r_square: -0.0596
# Epoch 47/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1754 - r_square: -0.0194 - val_loss: 0.1871 - val_r_square: -0.0831
# Epoch 48/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1745 - r_square: -0.0142 - val_loss: 0.1861 - val_r_square: -0.0775
# Epoch 49/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1769 - r_square: -0.0279 - val_loss: 0.1762 - val_r_square: -0.0199
# Epoch 50/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1759 - r_square: -0.0218 - val_loss: 0.1888 - val_r_square: -0.0931
# Epoch 51/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1754 - r_square: -0.0193 - val_loss: 0.1742 - val_r_square: -0.0087
# Epoch 52/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1746 - r_square: -0.0145 - val_loss: 0.1739 - val_r_square: -0.0069
# Epoch 53/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1748 - r_square: -0.0157 - val_loss: 0.1757 - val_r_square: -0.0174
# Epoch 54/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1769 - r_square: -0.0281 - val_loss: 0.1741 - val_r_square: -0.0077
# Epoch 55/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1749 - r_square: -0.0165 - val_loss: 0.1777 - val_r_square: -0.0287
# Epoch 56/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1758 - r_square: -0.0214 - val_loss: 0.1739 - val_r_square: -0.0067
# Epoch 57/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1740 - r_square: -0.0113 - val_loss: 0.1746 - val_r_square: -0.0106
# Epoch 58/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1745 - r_square: -0.0140 - val_loss: 0.1808 - val_r_square: -0.0470
# Epoch 59/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1752 - r_square: -0.0180 - val_loss: 0.1740 - val_r_square: -0.0073
# Epoch 60/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1750 - r_square: -0.0167 - val_loss: 0.1752 - val_r_square: -0.0143
# Epoch 61/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1753 - r_square: -0.0184 - val_loss: 0.1812 - val_r_square: -0.0488
# Epoch 62/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1752 - r_square: -0.0178 - val_loss: 0.1749 - val_r_square: -0.0126
# Epoch 63/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1745 - r_square: -0.0137 - val_loss: 0.1797 - val_r_square: -0.0401
# Epoch 64/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1752 - r_square: -0.0179 - val_loss: 0.1746 - val_r_square: -0.0107
# Epoch 65/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1752 - r_square: -0.0180 - val_loss: 0.1791 - val_r_square: -0.0371
# Epoch 66/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1758 - r_square: -0.0213 - val_loss: 0.1740 - val_r_square: -0.0074
# Epoch 67/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1744 - r_square: -0.0132 - val_loss: 0.1739 - val_r_square: -0.0066
# Epoch 68/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1752 - r_square: -0.0182 - val_loss: 0.1752 - val_r_square: -0.0141
# Epoch 69/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1756 - r_square: -0.0201 - val_loss: 0.1752 - val_r_square: -0.0142
# Epoch 70/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1748 - r_square: -0.0155 - val_loss: 0.1739 - val_r_square: -0.0065
# Epoch 71/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1747 - r_square: -0.0154 - val_loss: 0.1773 - val_r_square: -0.0262
# Epoch 72/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1747 - r_square: -0.0149 - val_loss: 0.1763 - val_r_square: -0.0208
# Epoch 73/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1748 - r_square: -0.0159 - val_loss: 0.1747 - val_r_square: -0.0114
# Epoch 74/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1751 - r_square: -0.0176 - val_loss: 0.1810 - val_r_square: -0.0477
# Epoch 75/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1747 - r_square: -0.0152 - val_loss: 0.1739 - val_r_square: -0.0068
# Epoch 76/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1754 - r_square: -0.0193 - val_loss: 0.1741 - val_r_square: -0.0077
# Epoch 77/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1752 - r_square: -0.0182 - val_loss: 0.1775 - val_r_square: -0.0276
# Epoch 78/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1754 - r_square: -0.0190 - val_loss: 0.1741 - val_r_square: -0.0080
# Epoch 79/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1754 - r_square: -0.0194 - val_loss: 0.1819 - val_r_square: -0.0529
# Epoch 80/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1743 - r_square: -0.0129 - val_loss: 0.1747 - val_r_square: -0.0117
# Epoch 81/150
# 703/703 [==============================] - 4s 5ms/step - loss: 0.1752 - r_square: -0.0179 - val_loss: 0.1745 - val_r_square: -0.0101
# Epoch 82/150
# 703/703 [==============================] - 4s 5ms/step - loss: 0.1750 - r_square: -0.0168 - val_loss: 0.1755 - val_r_square: -0.0161
# Epoch 83/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1764 - r_square: -0.0251 - val_loss: 0.1763 - val_r_square: -0.0205
# Epoch 84/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1758 - r_square: -0.0214 - val_loss: 0.1789 - val_r_square: -0.0357
# Epoch 85/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1757 - r_square: -0.0207 - val_loss: 0.1744 - val_r_square: -0.0098
# Epoch 86/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1739 - r_square: -0.0107 - val_loss: 0.1834 - val_r_square: -0.0616
# Epoch 87/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1745 - r_square: -0.0139 - val_loss: 0.1741 - val_r_square: -0.0082
# Epoch 88/150
# 703/703 [==============================] - 4s 5ms/step - loss: 0.1750 - r_square: -0.0167 - val_loss: 0.1745 - val_r_square: -0.0105
# Epoch 89/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1753 - r_square: -0.0184 - val_loss: 0.1763 - val_r_square: -0.0207
# Epoch 90/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1755 - r_square: -0.0198 - val_loss: 0.1739 - val_r_square: -0.0069
# Epoch 91/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1751 - r_square: -0.0176 - val_loss: 0.1750 - val_r_square: -0.0129
# Epoch 92/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1756 - r_square: -0.0206 - val_loss: 0.1810 - val_r_square: -0.0481
# Epoch 93/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1748 - r_square: -0.0160 - val_loss: 0.1771 - val_r_square: -0.0253
# Epoch 94/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1749 - r_square: -0.0165 - val_loss: 0.1795 - val_r_square: -0.0393
# Epoch 95/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1747 - r_square: -0.0154 - val_loss: 0.1748 - val_r_square: -0.0122
# Epoch 96/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1748 - r_square: -0.0159 - val_loss: 0.1739 - val_r_square: -0.0070
# Epoch 97/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1750 - r_square: -0.0169 - val_loss: 0.1752 - val_r_square: -0.0145
# Epoch 98/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1754 - r_square: -0.0193 - val_loss: 0.1873 - val_r_square: -0.0845
# Epoch 99/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1759 - r_square: -0.0224 - val_loss: 0.1781 - val_r_square: -0.0311
# Epoch 100/150
# 703/703 [==============================] - 2s 4ms/step - loss: 0.1746 - r_square: -0.0143 - val_loss: 0.1773 - val_r_square: -0.0265
# Epoch 101/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1751 - r_square: -0.0172 - val_loss: 0.1797 - val_r_square: -0.0401
# Epoch 102/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1752 - r_square: -0.0181 - val_loss: 0.2143 - val_r_square: -0.2406
# Epoch 103/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1752 - r_square: -0.0179 - val_loss: 0.1755 - val_r_square: -0.0158
# Epoch 104/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1742 - r_square: -0.0121 - val_loss: 0.1852 - val_r_square: -0.0723
# Epoch 105/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1757 - r_square: -0.0209 - val_loss: 0.1740 - val_r_square: -0.0071
# Epoch 106/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1742 - r_square: -0.0122 - val_loss: 0.1784 - val_r_square: -0.0329
# Epoch 107/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1748 - r_square: -0.0156 - val_loss: 0.1755 - val_r_square: -0.0157
# Epoch 108/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1753 - r_square: -0.0184 - val_loss: 0.1743 - val_r_square: -0.0091
# Epoch 109/150
# 703/703 [==============================] - 2s 3ms/step - loss: 0.1753 - r_square: -0.0185 - val_loss: 0.1798 - val_r_square: -0.0411
# Epoch 110/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1746 - r_square: -0.0144 - val_loss: 0.1848 - val_r_square: -0.0697
# Epoch 111/150
# 703/703 [==============================] - 4s 5ms/step - loss: 0.1748 - r_square: -0.0160 - val_loss: 0.1778 - val_r_square: -0.0296
# Epoch 112/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1763 - r_square: -0.0244 - val_loss: 0.1849 - val_r_square: -0.0706
# Epoch 113/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1757 - r_square: -0.0212 - val_loss: 0.1885 - val_r_square: -0.0912
# Epoch 114/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1749 - r_square: -0.0165 - val_loss: 0.1896 - val_r_square: -0.0977
# Epoch 115/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1753 - r_square: -0.0185 - val_loss: 0.1786 - val_r_square: -0.0338
# Epoch 116/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1750 - r_square: -0.0166 - val_loss: 0.1738 - val_r_square: -0.0063
# Epoch 117/150
# 703/703 [==============================] - 4s 5ms/step - loss: 0.1748 - r_square: -0.0157 - val_loss: 0.1782 - val_r_square: -0.0319
# Epoch 118/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1755 - r_square: -0.0196 - val_loss: 0.1778 - val_r_square: -0.0295
# Epoch 119/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1756 - r_square: -0.0201 - val_loss: 0.1997 - val_r_square: -0.1564
# Epoch 120/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1757 - r_square: -0.0209 - val_loss: 0.1813 - val_r_square: -0.0498
# Epoch 121/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1746 - r_square: -0.0144 - val_loss: 0.1740 - val_r_square: -0.0073
# Epoch 122/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1763 - r_square: -0.0247 - val_loss: 0.1758 - val_r_square: -0.0176
# Epoch 123/150
# 703/703 [==============================] - 2s 4ms/step - loss: 0.1747 - r_square: -0.0150 - val_loss: 0.1765 - val_r_square: -0.0216
# Epoch 124/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1755 - r_square: -0.0197 - val_loss: 0.1752 - val_r_square: -0.0141
# Epoch 125/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1758 - r_square: -0.0217 - val_loss: 0.1760 - val_r_square: -0.0192
# Epoch 126/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1753 - r_square: -0.0188 - val_loss: 0.1743 - val_r_square: -0.0089
# Epoch 127/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1758 - r_square: -0.0215 - val_loss: 0.1846 - val_r_square: -0.0689
# Epoch 128/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1747 - r_square: -0.0149 - val_loss: 0.1780 - val_r_square: -0.0302
# Epoch 129/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1755 - r_square: -0.0196 - val_loss: 0.1873 - val_r_square: -0.0846
# Epoch 130/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1749 - r_square: -0.0161 - val_loss: 0.1742 - val_r_square: -0.0085
# Epoch 131/150
# 703/703 [==============================] - 4s 5ms/step - loss: 0.1751 - r_square: -0.0177 - val_loss: 0.1766 - val_r_square: -0.0227
# Epoch 132/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1743 - r_square: -0.0128 - val_loss: 0.1743 - val_r_square: -0.0091
# Epoch 133/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1760 - r_square: -0.0227 - val_loss: 0.1767 - val_r_square: -0.0227
# Epoch 134/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1745 - r_square: -0.0141 - val_loss: 0.1758 - val_r_square: -0.0180
# Epoch 135/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1752 - r_square: -0.0180 - val_loss: 0.1746 - val_r_square: -0.0109
# Epoch 136/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1747 - r_square: -0.0154 - val_loss: 0.1768 - val_r_square: -0.0238
# Epoch 137/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1745 - r_square: -0.0139 - val_loss: 0.1756 - val_r_square: -0.0166
# Epoch 138/150
# 703/703 [==============================] - 4s 5ms/step - loss: 0.1751 - r_square: -0.0175 - val_loss: 0.1772 - val_r_square: -0.0260
# Epoch 139/150
# 703/703 [==============================] - 4s 5ms/step - loss: 0.1748 - r_square: -0.0159 - val_loss: 0.1806 - val_r_square: -0.0458
# Epoch 140/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1750 - r_square: -0.0167 - val_loss: 0.1786 - val_r_square: -0.0338
# Epoch 141/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1752 - r_square: -0.0179 - val_loss: 0.1739 - val_r_square: -0.0067
# Epoch 142/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1751 - r_square: -0.0172 - val_loss: 0.1764 - val_r_square: -0.0211
# Epoch 143/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1755 - r_square: -0.0196 - val_loss: 0.1744 - val_r_square: -0.0098
# Epoch 144/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1748 - r_square: -0.0158 - val_loss: 0.1741 - val_r_square: -0.0082
# Epoch 145/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1748 - r_square: -0.0159 - val_loss: 0.1740 - val_r_square: -0.0076
# Epoch 146/150
# 703/703 [==============================] - 3s 4ms/step - loss: 0.1744 - r_square: -0.0134 - val_loss: 0.1762 - val_r_square: -0.0199
# Epoch 147/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1747 - r_square: -0.0152 - val_loss: 0.1797 - val_r_square: -0.0404
# Epoch 148/150
# 703/703 [==============================] - 3s 5ms/step - loss: 0.1744 - r_square: -0.0135 - val_loss: 0.1744 - val_r_square: -0.0098
# Epoch 149/150
# 703/703 [==============================] - 6s 8ms/step - loss: 0.1747 - r_square: -0.0149 - val_loss: 0.1746 - val_r_square: -0.0108
# Epoch 150/150
# 703/703 [==============================] - 4s 6ms/step - loss: 0.1745 - r_square: -0.0138 - val_loss: 0.1775 - val_r_square: -0.0276

# %%
# Print the column names of your DataFrame
print(df.columns)
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'Sep_History',
#        'Aug_History', 'Jul_History', 'Jun_History', 'May_History',
#        'Apr_History', 'Sep_Balance', 'Aug_Balance', 'Jul_Balance',
#        'Jun_Balance', 'May_Balance', 'Apr_Balance', 'Sep_Pmt', 'Aug_Pmt',
#        'Jul_Pmt', 'Jun_Pmt', 'May_Pmt', 'Apr_Pmt', 'DEF_PAY'],
#       dtype='object')

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report

# %%
features = ['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'Sep_History', 'Aug_History',
            'Jul_History', 'Jun_History', 'May_History', 'Apr_History', 'Sep_Bal', 'Aug_Bal',
            'Jul_Bal', 'Jun_Bal', 'May_Bal', 'Apr_Bal', 'Sep_Pmt', 'Aug_Pmt', 'Jul_Pmt',
            'Jun_Pmt', 'May_Pmt', 'Apr_Pmt']
target = 'DEF_PAY'

# %%
# Extract features and target variable
X = df[features]
y = df[target]

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=3)

# Standardize the features (important for SVM)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Create an SVM classifier
svm_classifier = SVC(kernel='linear', C=1.0, random_state=3)

# %%
# Train the SVM model
svm_classifier.fit(X_train_scaled, y_train)
# Out:
# SVC(kernel='linear', random_state=3)

# %%
# Make predictions on the test set
y_pred = svm_classifier.predict(X_test_scaled)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
classification_report_output = classification_report(y_test, y_pred)

# %%
from sklearn.metrics import accuracy_score, classification_report

# Make predictions on the training set
y_train_pred = svm_classifier.predict(X_train_scaled)

# Evaluate the training performance
train_accuracy = accuracy_score(y_train, y_train_pred)
train_classification_report = classification_report(y_train, y_train_pred)

print("Training Performance:")
print(f'Training Accuracy: {train_accuracy:.4f}')
print('Training Classification Report:')
print(train_classification_report)

# Make predictions on the test set
y_test_pred = svm_classifier.predict(X_test_scaled)

# Evaluate the testing performance
test_accuracy = accuracy_score(y_test, y_test_pred)
test_classification_report = classification_report(y_test, y_test_pred)

print("\nTesting Performance:")
print(f'Testing Accuracy: {test_accuracy:.4f}')
print('Testing Classification Report:')
print(test_classification_report)
# Out:
# Training Performance:
# Training Accuracy: 0.8177
# Training Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89     17452
#            1       0.67      0.37      0.47      5048
#
#     accuracy                           0.82     22500
#    macro avg       0.75      0.66      0.68     22500
# weighted avg       0.80      0.82      0.80     22500
#
#
# Testing Performance:
# Testing Accuracy: 0.8297
# Testing Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.85      0.95      0.90      5912
#            1       0.67      0.38      0.49      1588
#
#     accuracy                           0.83      7500
#    macro avg       0.76      0.67      0.69      7500
# weighted avg       0.81      0.83      0.81      7500
